# %%
import pandas as pd

# Assuming the CSV file is in the same directory as your Python script
file_path = "mpii_human_pose.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to ensure it was read correctly
df
# Out:
#           ID           NAME  r ankle_X  r ankle_Y  r knee_X  r knee_Y  \
# 0          1  015601864.jpg        620        394       616       269
# 1          2  015599452.jpg         -1         -1        -1        -1
# 2          3  005808361.jpg        804        711       816       510
# 3          4  086617615.jpg        301        461       305       375
# 4          5  060111501.jpg        980        322       896       318
# ...      ...            ...        ...        ...       ...       ...
# 17367  17368  033474347.jpg        876        461       815       380
# 17368  17369  082650067.jpg       1038        656       950       504
# 17369  17370  072772110.jpg        562        617       558       539
# 17370  17371  039361034.jpg        496        377       466       322
# 17371  17372  084761779.jpg        362        350       347       297
#
#        r hip_X  r hip_Y  l hip_X  l hip_Y  ...  r shoulder_Y  l shoulder_X  \
# ...

# %%
# !pip install wheel
# !pip install pandas

# %%
df.head()
# Out:
#    ID           NAME  r ankle_X  r ankle_Y  r knee_X  r knee_Y  r hip_X  \
# 0   1  015601864.jpg        620        394       616       269      573
# 1   2  015599452.jpg         -1         -1        -1        -1      806
# 2   3  005808361.jpg        804        711       816       510      908
# 3   4  086617615.jpg        301        461       305       375      201
# 4   5  060111501.jpg        980        322       896       318      865
#
#    r hip_Y  l hip_X  l hip_Y  ...  r shoulder_Y  l shoulder_X  l shoulder_Y  \
# 0      185      647      188  ...           167           692           185
# 1      543      720      593  ...           281           719           299
# 2      438     1040      454  ...           253          1067           253
# 3      340      294      342  ...           261           314           264
# 4      248      943      226  ...           147           923           123
#
#    l elbow_X  l elbow_Y  l wrist_X  l wrist_Y     Scale  Activity  Category
# ...

# %%
from PIL import Image

# Assuming 'NAME' column contains the file names of the images
file_names = df['NAME']
file_names
# Loop through each file name and open the corresponding image
for file_name in file_names:
    # Assuming the images are in the same directory as your script
    image_path = file_name
    image = Image.open(image_path)
    image.show()  # Display the image
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 10
#       7 for file_name in file_names:
#       8     # Assuming the images are in the same directory as your script
#       9     image_path = file_name
# ---> 10     image = Image.open(image_path)
#      11     image.show()
#
# File ~\miniconda3\envs\opencv_env\lib\site-packages\PIL\Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\DELL\\Desktop\\project\\015601864.jpg'
